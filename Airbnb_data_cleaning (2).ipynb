# %% [markdown]
# ## Cleaning NYC Airbnb detailed listings dataset
# The goal of this notebook is to clean the raw airbnb Amsterdam dataset. The dataset can be found here:http://insideairbnb.com/get-the-data.html.

# %%
# Import the necessary packages
# data managing and display libs
import pandas as pd
import numpy as np
import os
import io

import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline 

import seaborn as sns

# %% [markdown]
# ## Get data from CSV

# %%
pd.set_option('display.max_rows',500)
listings= pd.read_csv('listings.csv')
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18291 entries, 0 to 18290
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            18291 non-null  int64
#  1   listing_url                                   18291 non-null  object
#  2   scrape_id                                     18291 non-null  int64
#  3   last_scraped                                  18291 non-null  object
#  4   name                                          18258 non-null  object
#  5   description                                   17994 non-null  object
#  6   neighborhood_overview                         12023 non-null  object
#  7   picture_url                                   18291 non-null  object
#  8   host_id                                       18291 non-null  int64
#  9   host_url                                      18291 non-null  object
#  10  host_name                                     18228 non-null  object
#  11  host_since                                    18228 non-null  object
#  12  host_location                                 18199 non-null  object
#  13  host_about                                    10474 non-null  object
#  14  host_response_time                            3937 non-null   object
#  15  host_response_rate                            3937 non-null   object
#  16  host_acceptance_rate                          7796 non-null   object
#  17  host_is_superhost                             18228 non-null  object
#  18  host_thumbnail_url                            18228 non-null  object
#  19  host_picture_url                              18228 non-null  object
#  20  host_neighbourhood                            12157 non-null  object
#  21  host_listings_count                           18228 non-null  float64
#  22  host_total_listings_count                     18228 non-null  float64
#  23  host_verifications                            18291 non-null  object
#  24  host_has_profile_pic                          18228 non-null  object
#  25  host_identity_verified                        18228 non-null  object
#  26  neighbourhood                                 12023 non-null  object
#  27  neighbourhood_cleansed                        18291 non-null  object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      18291 non-null  float64
#  30  longitude                                     18291 non-null  float64
#  31  property_type                                 18291 non-null  object
#  32  room_type                                     18291 non-null  object
#  33  accommodates                                  18291 non-null  int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                18269 non-null  object
#  36  bedrooms                                      17294 non-null  float64
#  37  beds                                          18186 non-null  float64
#  38  amenities                                     18291 non-null  object
#  39  price                                         18291 non-null  object
#  40  minimum_nights                                18291 non-null  int64
#  41  maximum_nights                                18291 non-null  int64
#  42  minimum_minimum_nights                        18288 non-null  float64
#  43  maximum_minimum_nights                        18288 non-null  float64
#  44  minimum_maximum_nights                        18288 non-null  float64
#  45  maximum_maximum_nights                        18288 non-null  float64
#  46  minimum_nights_avg_ntm                        18288 non-null  float64
#  47  maximum_nights_avg_ntm                        18288 non-null  float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              18291 non-null  object
#  50  availability_30                               18291 non-null  int64
#  51  availability_60                               18291 non-null  int64
#  52  availability_90                               18291 non-null  int64
#  53  availability_365                              18291 non-null  int64
#  54  calendar_last_scraped                         18291 non-null  object
#  55  number_of_reviews                             18291 non-null  int64
#  56  number_of_reviews_ltm                         18291 non-null  int64
#  57  number_of_reviews_l30d                        18291 non-null  int64
#  58  first_review                                  15902 non-null  object
#  59  last_review                                   15902 non-null  object
#  60  review_scores_rating                          15659 non-null  float64
#  61  review_scores_accuracy                        15649 non-null  float64
#  62  review_scores_cleanliness                     15649 non-null  float64
#  63  review_scores_checkin                         15641 non-null  float64
#  64  review_scores_communication                   15648 non-null  float64
#  65  review_scores_location                        15643 non-null  float64
#  66  review_scores_value                           15643 non-null  float64
#  67  license                                       0 non-null      float64
#  68  instant_bookable                              18291 non-null  object
#  69  calculated_host_listings_count                18291 non-null  int64
#  70  calculated_host_listings_count_entire_homes   18291 non-null  int64
#  71  calculated_host_listings_count_private_rooms  18291 non-null  int64
#  72  calculated_host_listings_count_shared_rooms   18291 non-null  int64
#  73  reviews_per_month                             15902 non-null  float64
# dtypes: float64(24), int64(17), object(33)
# memory usage: 10.3+ MB

# %%
listings.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20210208155251   2021-02-11
# 1  20168  https://www.airbnb.com/rooms/20168  20210208155251   2021-02-11
# 2  25428  https://www.airbnb.com/rooms/25428  20210208155251   2021-02-10
# 3  27886  https://www.airbnb.com/rooms/27886  20210208155251   2021-02-11
# 4  28871  https://www.airbnb.com/rooms/28871  20210208155251   2021-02-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely, spacious 1 bed apt in Center(with lift)
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Lovely apt in Centre ( lift & fireplace) near ...
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  <b>The space</b><br />In a monumental house ri...
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Located just in between famous central canals....
# 2                                                NaN
# 3         Central, quiet, safe, clean and beautiful.
# 4       Flower market , Leidseplein , Rembrantsplein
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/10272854/8dcc...     3159
# 1  https://a0.muscache.com/pictures/69979628/fd6a...    59484
# 2  https://a0.muscache.com/pictures/138431/7079a9...    56142
# 3  https://a0.muscache.com/pictures/02c2da9d-660e...    97647
# 4  https://a0.muscache.com/pictures/160889/362340...   124245
#
#                                    host_url  ... review_scores_communication  \
# 0    https://www.airbnb.com/users/show/3159  ...                        10.0
# 1   https://www.airbnb.com/users/show/59484  ...                        10.0
# 2   https://www.airbnb.com/users/show/56142  ...                        10.0
# 3   https://www.airbnb.com/users/show/97647  ...                        10.0
# 4  https://www.airbnb.com/users/show/124245  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    9.0                10.0     NaN                t
# 1                   10.0                 9.0     NaN                t
# 2                   10.0                10.0     NaN                f
# 3                   10.0                10.0     NaN                t
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              2                                           0
# 2                              1                                           1
# 3                              1                                           0
# 4                              2                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            0
# 3                                            1
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.92
# 1                                           0              2.54
# 2                                           0              0.13
# 3                                           0              1.98
# 4                                           0              2.63
#
# [5 rows x 74 columns]

# %% [markdown]
# The Detailed listings contains about 74 different features for each of the Airbnb locations. We need to do some EDA to check if we can trim down some features.

# %%
print("Detailed Listings row, cols: ", listings.shape)
# Out:
# Detailed Listings row, cols:  (18291, 74)

# %%
# check how the data types are distributed.
# pandas does its best to interpret the datatype while reading in
# however it is our duty to check if the datatype makes sense
listings.dtypes.value_counts()
# Out:
# object     33
# float64    24
# int64      17
# dtype: int64

# %% [markdown]
# There are about **18291** airbnb listings and each of these listing has associated with it **74 features** describing all aspects of the airbnb listing. However, some of these features might be having missing values, whereas some of them might not be relevant to Machine Learning. The data cleaning step will investigate and tackle these problems.

# %% [markdown]
# ## Data Cleaning
# The focus of this notebook is on cleaning the data and storing the cleaned version.  The strategy employed for cleaning the data is as follows:
# - Drop columns that are not relevant to the problem. Example: URL, host picture etc.
# - Find missing values for each column.
# - Drop columns which have more than 20% missing data. Make a note of the columns.
# - Convert columns to their correct data type.
# - Subset the dataset based on certain criterion. Ex: property_type = Apartment/House/Townhouse/Condo
# - One-hot-encode the categorical variables.

# %% [markdown]
# ### Drop columns
# #### Checking irrelevant Object types
# Using `select_dtypes` we can filter out the desired type of columns.

# %%
listings.select_dtypes(include=['object']).columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed', 'property_type', 'room_type',
#        'bathrooms_text', 'amenities', 'price', 'has_availability',
#        'calendar_last_scraped', 'first_review', 'last_review',
#        'instant_bookable'],
#       dtype='object')

# %% [markdown]
# By inspecting some values of object types, it becomes evident that some columns are just not that useful for our analysis. Example, the urls, last_scraped etc. Shown below are a list of columns that we can safely drop without much loss of information needed for our analysis. I have also displayed the head of the object columns to get a sense of why we can drop these columns.

# %%
listings.select_dtypes(include=['object']).head()
# Out:
#                           listing_url last_scraped  \
# 0   https://www.airbnb.com/rooms/2818   2021-02-11
# 1  https://www.airbnb.com/rooms/20168   2021-02-11
# 2  https://www.airbnb.com/rooms/25428   2021-02-10
# 3  https://www.airbnb.com/rooms/27886   2021-02-11
# 4  https://www.airbnb.com/rooms/28871   2021-02-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely, spacious 1 bed apt in Center(with lift)
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Lovely apt in Centre ( lift & fireplace) near ...
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  <b>The space</b><br />In a monumental house ri...
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Located just in between famous central canals....
# 2                                                NaN
# 3         Central, quiet, safe, clean and beautiful.
# 4       Flower market , Leidseplein , Rembrantsplein
#
#                                          picture_url  \
# 0  https://a0.muscache.com/pictures/10272854/8dcc...
# 1  https://a0.muscache.com/pictures/69979628/fd6a...
# 2  https://a0.muscache.com/pictures/138431/7079a9...
# 3  https://a0.muscache.com/pictures/02c2da9d-660e...
# 4  https://a0.muscache.com/pictures/160889/362340...
#
#                                    host_url  host_name  host_since  \
# 0    https://www.airbnb.com/users/show/3159     Daniel  2008-09-24
# 1   https://www.airbnb.com/users/show/59484  Alexander  2009-12-02
# 2   https://www.airbnb.com/users/show/56142       Joan  2009-11-20
# 3   https://www.airbnb.com/users/show/97647       Flip  2010-03-23
# 4  https://www.airbnb.com/users/show/124245      Edwin  2010-05-13
#
#                                host_location  ...              property_type  \
# 0  Amsterdam, Noord-Holland, The Netherlands  ...  Private room in apartment
# 1  Amsterdam, Noord-Holland, The Netherlands  ...  Private room in townhouse
# 2          New York, New York, United States  ...           Entire apartment
# 3  Amsterdam, Noord-Holland, The Netherlands  ...  Private room in houseboat
# 4  Amsterdam, Noord-Holland, The Netherlands  ...  Private room in apartment
#
#          room_type    bathrooms_text  \
# 0     Private room  1.5 shared baths
# 1     Private room    1 private bath
# 2  Entire home/apt            1 bath
# 3     Private room         1.5 baths
# 4     Private room     1 shared bath
#
#                                            amenities    price  \
# 0  ["Hangers", "Coffee maker", "Paid parking on p...   $59.00
# 1  ["Essentials", "Bed linens", "Hot water", "Han...  $129.00
# 2  ["Hangers", "Elevator", "Cooking basics", "Dis...  $125.00
# 3  ["Patio or balcony", "Hangers", "Dishes and si...  $125.00
# 4  ["Hot water", "Essentials", "Smoke alarm", "Ha...   $75.00
#
#   has_availability calendar_last_scraped first_review last_review  \
# 0                t            2021-02-11   2009-03-30  2020-02-14
# 1                t            2021-02-11   2010-03-02  2020-04-09
# 2                t            2021-02-10   2018-01-21  2020-02-09
# 3                t            2021-02-11   2012-01-09  2020-07-25
# 4                t            2021-02-10   2010-08-22  2020-09-20
#
#   instant_bookable
# 0                t
# 1                t
# 2                f
# 3                t
# 4                f
#
# [5 rows x 33 columns]

# %% [markdown]
# #### checking irrelevant float64 types

# %%
listings.select_dtypes(include=['float64']).columns
# Out:
# Index(['host_listings_count', 'host_total_listings_count',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude', 'bathrooms',
#        'bedrooms', 'beds', 'minimum_minimum_nights', 'maximum_minimum_nights',
#        'minimum_maximum_nights', 'maximum_maximum_nights',
#        'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'reviews_per_month'],
#       dtype='object')

# %%
listings.select_dtypes(include=['float64']).head()
# Out:
#    host_listings_count  host_total_listings_count  \
# 0                  1.0                        1.0
# 1                  2.0                        2.0
# 2                  2.0                        2.0
# 3                  1.0                        1.0
# 4                  2.0                        2.0
#
#    neighbourhood_group_cleansed  latitude  longitude  bathrooms  bedrooms  \
# 0                           NaN  52.36575    4.94142        NaN       1.0
# 1                           NaN  52.36509    4.89354        NaN       1.0
# 2                           NaN  52.37297    4.88339        NaN       1.0
# 3                           NaN  52.38761    4.89188        NaN       1.0
# 4                           NaN  52.36610    4.88953        NaN       1.0
#
#    beds  minimum_minimum_nights  maximum_minimum_nights  ...  \
# 0   2.0                     3.0                     3.0  ...
# 1   1.0                     1.0                     4.0  ...
# 2   1.0                    14.0                    14.0  ...
# 3   1.0                     2.0                     2.0  ...
# 4   1.0                     2.0                     2.0  ...
#
#    calendar_updated  review_scores_rating  review_scores_accuracy  \
# 0               NaN                  98.0                    10.0
# 1               NaN                  89.0                    10.0
# 2               NaN                 100.0                    10.0
# 3               NaN                  99.0                    10.0
# 4               NaN                  97.0                    10.0
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       10.0                   10.0
# 1                       10.0                   10.0
# 2                       10.0                   10.0
# 3                       10.0                   10.0
# 4                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                    10.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#    license  reviews_per_month
# 0      NaN               1.92
# 1      NaN               2.54
# 2      NaN               0.13
# 3      NaN               1.98
# 4      NaN               2.63
#
# [5 rows x 24 columns]

# %% [markdown]
# #### checking irrelevant int64 types

# %%
listings.select_dtypes(include=['int64']).columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'accommodates', 'minimum_nights',
#        'maximum_nights', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms'],
#       dtype='object')

# %%
listings.select_dtypes(include=['int64']).head()
# Out:
#       id       scrape_id  host_id  accommodates  minimum_nights  \
# 0   2818  20210208155251     3159             2               3
# 1  20168  20210208155251    59484             2               1
# 2  25428  20210208155251    56142             3              14
# 3  27886  20210208155251    97647             2               2
# 4  28871  20210208155251   124245             2               2
#
#    maximum_nights  availability_30  availability_60  availability_90  \
# 0            1125               29               46               60
# 1             365                0                0                0
# 2             180                6               36               66
# 3             730               27               55               79
# 4            1825               30               53               78
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0               139                278                      1
# 1                 0                339                     19
# 2               251                  5                      0
# 3               136                219                      6
# 4               338                336                     13
#
#    number_of_reviews_l30d  calculated_host_listings_count  \
# 0                       0                               1
# 1                       0                               2
# 2                       0                               1
# 3                       0                               1
# 4                       0                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            1
# 3                                            0
# 4                                            0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             1
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0

# %%
# Removing irrelevant columns which is not required for EDA or ML process

df_dl_clean_df = listings.drop(['listing_url','scrape_id','last_scraped','name','picture_url','host_url','host_name','host_thumbnail_url','host_picture_url',
                                          'host_listings_count','calendar_last_scraped', 'minimum_minimum_nights','maximum_maximum_nights','maximum_minimum_nights',
                                          'minimum_maximum_nights','minimum_nights_avg_ntm', 'maximum_nights_avg_ntm','availability_30','availability_60','availability_90',
                                          'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin','review_scores_communication', 'review_scores_location',
                                          'review_scores_value','review_scores_rating','number_of_reviews_ltm','number_of_reviews_l30d','first_review',
                                          'host_since','host_total_listings_count', 'last_review','host_location','amenities','host_verifications','reviews_per_month','beds' ],axis=1)

# %%
print("Shape of the dataset after dropping: ", df_dl_clean_df.shape)
# Out:
# Shape of the dataset after dropping:  (18291, 36)

# %% [markdown]
# ### Missing Value Statistics
# An important step in data cleaning is identifying columns with missing values. Let's first calculate the missing value statistics.

# %%
# missing data percentage
def missing_data_percentage(df):
    missing_info = df.isnull().sum().to_frame()
    missing_info.columns = ['Number_of_missing_data']
    missing_info['Percent_data_missing']= np.round(100*(missing_info['Number_of_missing_data']/df.shape[0]))
    missing_info.sort_values(by=['Number_of_missing_data'],ascending=False,inplace=True)
    return missing_info


Proportion_missing=missing_data_percentage(df_dl_clean_df)
Proportion_missing[Proportion_missing.Percent_data_missing>20]
# Out:
#                               Number_of_missing_data  Percent_data_missing
# calendar_updated                               18291                 100.0
# license                                        18291                 100.0
# bathrooms                                      18291                 100.0
# neighbourhood_group_cleansed                   18291                 100.0
# host_response_time                             14354                  78.0
# host_response_rate                             14354                  78.0
# host_acceptance_rate                           10495                  57.0
# host_about                                      7817                  43.0
# neighbourhood                                   6268                  34.0
# neighborhood_overview                           6268                  34.0
# host_neighbourhood                              6134                  34.0

# %% [markdown]
# As we can see in the table above, few columns have 100% missing data. We will be dropping these columns and upon close observation, it makes sense to drop the columns which have more than 20% missing data.

# %%
sns.heatmap(df_dl_clean_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
list(Proportion_missing[Proportion_missing.Percent_data_missing>20].index)
# Out:
# ['calendar_updated',
#  'license',
#  'bathrooms',
#  'neighbourhood_group_cleansed',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_about',
#  'neighbourhood',
#  'neighborhood_overview',
#  'host_neighbourhood']

# %%
df_dl_clean_df=df_dl_clean_df.drop(list(Proportion_missing[Proportion_missing.Percent_data_missing>20].index),axis='columns')
print(df_dl_clean_df.shape)
# Out:
# (18291, 25)

# %% [markdown]
# At this point, we have not fully dealt with missing values. But before we move forward with handling missing values, let's first validate that each of the variable is of the correct type, i.e, categorical and boolean type. Representing all string columns as **object type** is not an effective approach. We need to convert the object types to categorical or boolean if necessary. Another advantage of converting them from object to categorical/boolean is that we can make use of `pd.get_dummies()` to easily one-hot-encode the variables.

# %% [markdown]
# ### Convert object types to categorical and boolean variables
# Shown below is the head of all the object types in the dataset. By inspecting these variables, we can clearly see that some of these object types are actually categorical variables, some are boolean variables and some are text variables like *summary* and *description*. Our task is to identify categorical variables and separate them from text variables. Later, further down in the notebook, we will one-hot-encode all the categorical variables.

# %%
df_dl_clean_df.select_dtypes(['object']).head()
# Out:
#                                          description host_is_superhost  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...                 t
# 1  17th century Dutch townhouse in the heart of t...                 f
# 2  Lovely apt in Centre ( lift & fireplace) near ...                 t
# 3  Stylish and romantic houseboat on fantastic hi...                 t
# 4  <b>The space</b><br />In a monumental house ri...                 t
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      f
# 3                    t                      t
# 4                    t                      t
#
#                    neighbourhood_cleansed              property_type  \
# 0  Oostelijk Havengebied - Indische Buurt  Private room in apartment
# 1                            Centrum-Oost  Private room in townhouse
# 2                            Centrum-West           Entire apartment
# 3                            Centrum-West  Private room in houseboat
# 4                            Centrum-Oost  Private room in apartment
#
#          room_type    bathrooms_text    price has_availability  \
# 0     Private room  1.5 shared baths   $59.00                t
# 1     Private room    1 private bath  $129.00                t
# 2  Entire home/apt            1 bath  $125.00                t
# 3     Private room         1.5 baths  $125.00                t
# 4     Private room     1 shared bath   $75.00                t
#
#   instant_bookable
# 0                t
# 1                t
# 2                f
# 3                t
# 4                f

# %%
# collect all variables which need to be dummy encoded.
categorical_types = ['host_is_superhost',
                     'host_has_profile_pic',
                     'host_identity_verified',
                     'property_type',
                     'room_type',
                     'has_availability',
                     'instant_bookable',
                    'bathrooms_text']

# %%
df_dl_clean_df[categorical_types].dtypes
# Out:
# host_is_superhost         object
# host_has_profile_pic      object
# host_identity_verified    object
# property_type             object
# room_type                 object
# has_availability          object
# instant_bookable          object
# bathrooms_text            object
# dtype: object

# %% [markdown]
# As we can see, these columns are all of the type object. Representing them as categories is much more efficient.

# %%
df_dl_clean_df[categorical_types] = df_dl_clean_df[categorical_types].apply(lambda x: x.astype('category'), 
                                                                                axis='rows')
df_dl_clean_df[categorical_types].dtypes
# Out:
# host_is_superhost         category
# host_has_profile_pic      category
# host_identity_verified    category
# property_type             category
# room_type                 category
# has_availability          category
# instant_bookable          category
# bathrooms_text            category
# dtype: object

# %% [markdown]
# ### Subset the dataset
# #### Checking for unique values in each category
# Let's check how many unique values each of these columns have. This can be achieved using the `pd.Series.nunique` method.

# %%
# Calculate number of unique values for each label: num_unique_labels
num_unique_values = df_dl_clean_df[categorical_types].apply(pd.Series.nunique, axis='rows')
print(num_unique_values)

# Plot number of unique values for each label
num_unique_values.plot(kind='bar')
# Label the axes
plt.xlabel('Labels')
plt.ylabel('Number of unique values')

# Display the plot
plt.show()
# Out:
# host_is_superhost          2
# host_has_profile_pic       2
# host_identity_verified     2
# property_type             65
# room_type                  4
# has_availability           2
# instant_bookable           2
# bathrooms_text            27
# dtype: int64

# %% [markdown]
# It appears there are far too many property types in this data. Let's check why that is. Looking at the below numbers, we can see that NYC has many peculiar properties, for instance, *Treehouse*, *boat*, *Earth house* etc. To stay focused, we will restrict our analysis to *Apartment*, *House*, *Townhouse*, *condominium* and *private room*.

# %%
df_dl_clean_df.property_type.value_counts()
# Out:
# Entire apartment                      11393
# Private room in apartment              2218
# Entire house                           1198
# Entire townhouse                        472
# Private room in bed and breakfast       344
# Private room in house                   339
# Entire condominium                      261
# Entire loft                             261
# Houseboat                               199
# Boat                                    198
# Private room in townhouse               168
# Entire serviced apartment               149
# Room in boutique hotel                  135
# Private room in houseboat               117
# Private room in guest suite             103
# Private room in boat                     96
# Room in hotel                            90
# Private room in condominium              83
# Private room in loft                     55
# Room in bed and breakfast                49
# Entire guest suite                       42
# Shared room in apartment                 29
# Entire villa                             28
# Private room in hostel                   26
# Room in hostel                           21
# Private room in guesthouse               19
# Room in serviced apartment               18
# Entire guesthouse                        16
# Private room                             14
# Entire cottage                           13
# Private room in serviced apartment       13
# Private room in earth house              11
# Shared room in hostel                     9
# Tiny house                                9
# Private room in tiny house                9
# Private room in villa                     8
# Room in aparthotel                        8
# Entire place                              8
# Private room in farm stay                 7
# Shared room in boat                       5
# Entire floor                              4
# Entire cabin                              4
# Entire bungalow                           4
# Barn                                      4
# Private room in cabin                     3
# Entire bed and breakfast                  3
# Shared room in bed and breakfast          2
# Shared room in house                      2
# Shared room in houseboat                  2
# Private room in dome house                2
# Private room in island                    2
# Private room in floor                     2
# Campsite                                  2
# Camper/RV                                 2
# Yurt                                      2
# Private room in lighthouse                1
# Room in casa particular                   1
# Private room in bungalow                  1
# Entire home/apt                           1
# Entire chalet                             1
# Earth house                               1
# Cave                                      1
# Shared room in loft                       1
# Bus                                       1
# Tipi                                      1
# Name: property_type, dtype: int64

# %% [markdown]
# Since I am subsetting the dataset, I created a new one, so that we have a copy of the original dataset with all the property types.

# %%
df_dl_clean_df.to_csv("detailed_listings_without_subset_partially_cleaned.csv", index=False)

# %%
def top7_categories(df,variable):
    return list(df[variable].value_counts().nlargest(7).index.tolist())

# %%
top7_categories(df_dl_clean_df,'property_type')
# Out:
# ['Entire apartment',
#  'Private room in apartment',
#  'Entire house',
#  'Entire townhouse',
#  'Private room in bed and breakfast',
#  'Private room in house',
#  'Entire condominium']

# %%
# Subset the data to include few property types
df_airbnb = df_dl_clean_df[df_dl_clean_df.property_type.isin(top7_categories(df_dl_clean_df,'property_type'))]

# %%
# let pandas know that to use a copy instead of a view
df_airbnb = df_airbnb.copy()

# We need to remove unused categories since we are using type category,
# the removed categories are retained with count of 0.
# so, we need to explicitly remove the unused categories.
df_airbnb.loc[:, 'property_type'] = df_airbnb.loc[:,'property_type'].cat.remove_unused_categories()

# %%
df_airbnb.property_type.value_counts()
# Out:
# Entire apartment                     11393
# Private room in apartment             2218
# Entire house                          1198
# Entire townhouse                       472
# Private room in bed and breakfast      344
# Private room in house                  339
# Entire condominium                     261
# Name: property_type, dtype: int64

# %%
df_airbnb.head()
# Out:
#       id                                        description  host_id  \
# 0   2818  Quiet Garden View Room & Super Fast WiFi<br />...     3159
# 2  25428  Lovely apt in Centre ( lift & fireplace) near ...    56142
# 4  28871  <b>The space</b><br />In a monumental house ri...   124245
# 5  29051  This room can also accomodate 2 people.  For a...   124245
# 6  31080  <b>The space</b><br />My apartment is light an...   133488
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                 t                    t                      t
# 2                 t                    t                      f
# 4                 t                    t                      t
# 5                 t                    t                      t
# 6                 f                    t                      t
#
#                    neighbourhood_cleansed  latitude  longitude  \
# 0  Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 2                            Centrum-West  52.37297    4.88339
# 4                            Centrum-Oost  52.36610    4.88953
# 5                            Centrum-Oost  52.36607    4.89100
# 6                                    Zuid  52.35132    4.84838
#
#                property_type  ... minimum_nights  maximum_nights  \
# 0  Private room in apartment  ...              3            1125
# 2           Entire apartment  ...             14             180
# 4  Private room in apartment  ...              2            1825
# 5  Private room in apartment  ...              2             730
# 6           Entire apartment  ...              3             365
#
#   has_availability  availability_365 number_of_reviews  instant_bookable  \
# 0                t               139               278                 t
# 2                t               251                 5                 f
# 4                t               338               336                 f
# 5                t               355               480                 f
# 6                t                 0                32                 f
#
#    calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                               1                                           0
# 2                               1                                           1
# 4                               2                                           0
# 5                               2                                           0
# 6                               1                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 2                                             0
# 4                                             2
# 5                                             2
# 6                                             0
#
#    calculated_host_listings_count_shared_rooms
# 0                                            0
# 2                                            0
# 4                                            0
# 5                                            0
# 6                                            0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Missing Value Statistics for the subset

# %%
missing_df = missing_data_percentage(df_airbnb)
missing_df
# Out:
#                                               Number_of_missing_data  \
# bedrooms                                                         768
# description                                                      252
# host_is_superhost                                                 63
# host_has_profile_pic                                              63
# host_identity_verified                                            63
# bathrooms_text                                                     6
# minimum_nights                                                     0
# calculated_host_listings_count_private_rooms                       0
# calculated_host_listings_count_entire_homes                        0
# calculated_host_listings_count                                     0
# instant_bookable                                                   0
# number_of_reviews                                                  0
# availability_365                                                   0
# has_availability                                                   0
# maximum_nights                                                     0
# id                                                                 0
# price                                                              0
# accommodates                                                       0
# room_type                                                          0
# property_type                                                      0
# longitude                                                          0
# latitude                                                           0
# neighbourhood_cleansed                                             0
# host_id                                                            0
# calculated_host_listings_count_shared_rooms                        0
#
#                                               Percent_data_missing
# bedrooms                                                       5.0
# description                                                    2.0
# host_is_superhost                                              0.0
# host_has_profile_pic                                           0.0
# host_identity_verified                                         0.0
# bathrooms_text                                                 0.0
# minimum_nights                                                 0.0
# calculated_host_listings_count_private_rooms                   0.0
# calculated_host_listings_count_entire_homes                    0.0
# calculated_host_listings_count                                 0.0
# instant_bookable                                               0.0
# number_of_reviews                                              0.0
# availability_365                                               0.0
# has_availability                                               0.0
# maximum_nights                                                 0.0
# id                                                             0.0
# price                                                          0.0
# accommodates                                                   0.0
# room_type                                                      0.0
# property_type                                                  0.0
# longitude                                                      0.0
# latitude                                                       0.0
# neighbourhood_cleansed                                         0.0
# host_id                                                        0.0
# calculated_host_listings_count_shared_rooms                    0.0

# %% [markdown]
# The missing values for columns starting with host seem to have a pattern. Since all these columns have 63 missing values, it could be possible that the data is missing purpose.

# %%
# collect all the columns which have missing values
cols_missing_values = list(missing_df[Proportion_missing.Number_of_missing_data > 0].index)

df_airbnb_missing_values = df_airbnb[cols_missing_values]
df_airbnb_missing_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 0 to 18290
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   bedrooms                15457 non-null  float64
#  1   description             15973 non-null  object
#  2   host_is_superhost       16162 non-null  category
#  3   host_has_profile_pic    16162 non-null  category
#  4   host_identity_verified  16162 non-null  category
#  5   bathrooms_text          16219 non-null  category
# dtypes: category(4), float64(1), object(1)
# memory usage: 445.3+ KB
# <ipython-input-36-aaaf711b43a5>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cols_missing_values = list(missing_df[Proportion_missing.Number_of_missing_data > 0].index)

# %% [markdown]
# Check if the 63 missing values of host columns are are missing together.

# %%
host_cols = list(df_airbnb_missing_values.columns[df_airbnb_missing_values.columns.str.contains('host')])
df_airbnb_missing_values[host_cols][df_airbnb_missing_values.host_identity_verified.isnull()]
# Out:
#       host_is_superhost host_has_profile_pic host_identity_verified
# 203                 NaN                  NaN                    NaN
# 690                 NaN                  NaN                    NaN
# 898                 NaN                  NaN                    NaN
# 1404                NaN                  NaN                    NaN
# 1716                NaN                  NaN                    NaN
# 1885                NaN                  NaN                    NaN
# 2045                NaN                  NaN                    NaN
# 2509                NaN                  NaN                    NaN
# 2751                NaN                  NaN                    NaN
# 3371                NaN                  NaN                    NaN
# 3493                NaN                  NaN                    NaN
# 3663                NaN                  NaN                    NaN
# 3780                NaN                  NaN                    NaN
# 3914                NaN                  NaN                    NaN
# 3936                NaN                  NaN                    NaN
# 4117                NaN                  NaN                    NaN
# 4389                NaN                  NaN                    NaN
# 4619                NaN                  NaN                    NaN
# 6141                NaN                  NaN                    NaN
# 6282                NaN                  NaN                    NaN
# 6464                NaN                  NaN                    NaN
# 6585                NaN                  NaN                    NaN
# 6788                NaN                  NaN                    NaN
# 7844                NaN                  NaN                    NaN
# 8072                NaN                  NaN                    NaN
# 8189                NaN                  NaN                    NaN
# 8992                NaN                  NaN                    NaN
# 9082                NaN                  NaN                    NaN
# 9360                NaN                  NaN                    NaN
# 9841                NaN                  NaN                    NaN
# 9881                NaN                  NaN                    NaN
# 10089               NaN                  NaN                    NaN
# 10557               NaN                  NaN                    NaN
# 10737               NaN                  NaN                    NaN
# 10897               NaN                  NaN                    NaN
# 10916               NaN                  NaN                    NaN
# 11051               NaN                  NaN                    NaN
# 11081               NaN                  NaN                    NaN
# 11138               NaN                  NaN                    NaN
# 11315               NaN                  NaN                    NaN
# 11431               NaN                  NaN                    NaN
# 11911               NaN                  NaN                    NaN
# 12199               NaN                  NaN                    NaN
# 12375               NaN                  NaN                    NaN
# 12429               NaN                  NaN                    NaN
# 12477               NaN                  NaN                    NaN
# 12558               NaN                  NaN                    NaN
# 12564               NaN                  NaN                    NaN
# 12585               NaN                  NaN                    NaN
# 12663               NaN                  NaN                    NaN
# 12664               NaN                  NaN                    NaN
# 12709               NaN                  NaN                    NaN
# 12778               NaN                  NaN                    NaN
# 12919               NaN                  NaN                    NaN
# 13422               NaN                  NaN                    NaN
# 13589               NaN                  NaN                    NaN
# 13657               NaN                  NaN                    NaN
# 13852               NaN                  NaN                    NaN
# 14007               NaN                  NaN                    NaN
# 14017               NaN                  NaN                    NaN
# 14034               NaN                  NaN                    NaN
# 15030               NaN                  NaN                    NaN
# 17920               NaN                  NaN                    NaN

# %% [markdown]
# Yes, as suspected, these host columns have missing values for the same observations.
# according to our findings, it is clearly visible that the missing value in these columns are for same observation, might be due to some reason.

# %% [markdown]
# ### Handling Missing Values
# - For columns containing text, we will be replacing them with an empty string.
# - For categorical columns, we will be replacing missing values with the mode.
# - For continuous columns, we will be replacing the missing values with the median.
#
# I will be using sklearn's `SimpleImputer` to replace the missing values.

# %% [markdown]
# **TEXT COLUMNS**:

# %%
df_airbnb_clean = df_airbnb.copy(deep=True)
df_airbnb_clean.shape
# Out:
# (16225, 25)

# %%
df_airbnb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16225 entries, 0 to 18290
# Data columns (total 25 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            16225 non-null  int64
#  1   description                                   15973 non-null  object
#  2   host_id                                       16225 non-null  int64
#  3   host_is_superhost                             16162 non-null  category
#  4   host_has_profile_pic                          16162 non-null  category
#  5   host_identity_verified                        16162 non-null  category
#  6   neighbourhood_cleansed                        16225 non-null  object
#  7   latitude                                      16225 non-null  float64
#  8   longitude                                     16225 non-null  float64
#  9   property_type                                 16225 non-null  category
#  10  room_type                                     16225 non-null  category
#  11  accommodates                                  16225 non-null  int64
#  12  bathrooms_text                                16219 non-null  category
#  13  bedrooms                                      15457 non-null  float64
#  14  price                                         16225 non-null  object
#  15  minimum_nights                                16225 non-null  int64
#  16  maximum_nights                                16225 non-null  int64
#  17  has_availability                              16225 non-null  category
#  18  availability_365                              16225 non-null  int64
#  19  number_of_reviews                             16225 non-null  int64
#  20  instant_bookable                              16225 non-null  category
#  21  calculated_host_listings_count                16225 non-null  int64
#  22  calculated_host_listings_count_entire_homes   16225 non-null  int64
#  23  calculated_host_listings_count_private_rooms  16225 non-null  int64
#  24  calculated_host_listings_count_shared_rooms   16225 non-null  int64
# dtypes: category(8), float64(3), int64(11), object(3)
# memory usage: 2.4+ MB

# %%
# to avoid setcopywithwarning use .copy() - this will tell pandas use a copy and not a view.
df_airbnb_clean.loc[df_airbnb_clean.description.isna().copy(), 'description'] = ''

# %% [markdown]
# **CATEGORICAL COLUMNS**:

# %%
from sklearn.impute import SimpleImputer
category_missing_cols = ['host_has_profile_pic', 'host_identity_verified', 
                         'host_is_superhost']

float_missing_cols = ['bedrooms']

# %% [markdown]
# For validation purpose, lets first check the `float_missing_cols`. Example, check the bathrooms and bedrooms columns, you will notice there are some NaN values in there. If the missing value imputation is successful, then we should expect to see these NaN values replaced by their median values.

# %%
def replace_missing_values(cols, df):
    '''
        Takes a list of columns and a dataframe and imputes based on
        the column type. If it is object type, then most_frequent value
        is used for imputation. If it is a float/int type, then the median
        value is used for imputation.
        arguments:
            cols: list of columns
            df : dataframe containing these columns.
        returns:
            df: the imputed dataframe
    '''
    for col in cols:
        if type(df[col].dtype) is pd.core.dtypes.dtypes.CategoricalDtype:
            print("Imputing {} column with most frequent value".format(col))
            mode_imputer = SimpleImputer(strategy='most_frequent')
            df.loc[:, col] = mode_imputer.fit_transform(df[[col]])
        elif df[col].dtype == 'float64' or df[col].dtype == 'int64':
            print("Imputing {} column with median value".format(col))
            median_imputer = SimpleImputer(strategy='median')
            df.loc[:, col] = median_imputer.fit_transform(df[[col]])
        else:
            raise ValueError("Invalid column type")
    
    return df

# %%
df_airbnb_clean = replace_missing_values(float_missing_cols, df_airbnb_clean)
df_airbnb_clean = replace_missing_values(category_missing_cols, df_airbnb_clean)
# Out:
# Imputing bedrooms column with median value
# Imputing host_has_profile_pic column with most frequent value
# Imputing host_identity_verified column with most frequent value
# Imputing host_is_superhost column with most frequent value

# %% [markdown]
# After imputation, we have successfully removed all the missing values.

# %%
sns.heatmap(df_airbnb_clean.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df_airbnb_clean.isna().sum()
# Out:
# id                                              0
# description                                     0
# host_id                                         0
# host_is_superhost                               0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood_cleansed                          0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms_text                                  6
# bedrooms                                        0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# has_availability                                0
# availability_365                                0
# number_of_reviews                               0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# dtype: int64

# %% [markdown]
# ## Clean the columns
# Some columns like `price` are represented as objects since we have a dollar sign. Before we proceed further with our analysis, we need to clean these columns.

# %% [markdown]
# #### Cleaning price column

# %%
df_airbnb_clean.price.head()
# Out:
# 0     $59.00
# 2    $125.00
# 4     $75.00
# 5     $55.00
# 6    $219.00
# Name: price, dtype: object

# %%
import re
 # as Price variable due to dollar sign been extracted as object type, we remove the dollar sign and change its dtype to float.
df_airbnb_clean['price']=df_airbnb.price.str.replace('$','').str.replace(',', '').astype('float')
# Out:
# <ipython-input-46-d705cd9f2956>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df_airbnb_clean['price']=df_airbnb.price.str.replace('$','').str.replace(',', '').astype('float')

# %%
df_airbnb_clean.price.head()
# Out:
# 0     59.0
# 2    125.0
# 4     75.0
# 5     55.0
# 6    219.0
# Name: price, dtype: float64

# %%
df_airbnb_clean[['price']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Price has quite many outliers, we will deal with outliers in the next stage.

# %% [markdown]
# Changing "bathroom_text" column to "Number of bathroom".
# Changing its dtype and format

# %%
df_airbnb_clean.bathrooms_text.head()
# Out:
# 0    1.5 shared baths
# 2              1 bath
# 4       1 shared bath
# 5       1 shared bath
# 6              1 bath
# Name: bathrooms_text, dtype: category
# Categories (27, object): ['0 baths', '0 shared baths', '1 bath', '1 private bath', ..., '8 baths', 'Half-bath', 'Private half-bath', 'Shared half-bath']

# %%
# creating new column/variable which describe how many bathrooms are available in that rental place.

# renaming some categories to approtiate categories 
df_airbnb_clean=df_airbnb_clean.replace({'bathrooms_text' : { 'Private half-bath' : '0.5 private bath', 'Shared half-bath' : '0.5 shared bath', 'Half-bath' : '0.5 bath' }})

# creating new column to describe number of bathrooms
df_airbnb_clean['Number_of_bathrooms']=df_airbnb_clean['bathrooms_text'].str.split(' ',1).str[0].astype('float')

# Droping Bathroom text column
df_airbnb_clean=df_airbnb_clean.drop(['bathrooms_text'],axis=1)

# %%
df_airbnb_clean.Number_of_bathrooms.head()
# Out:
# 0    1.5
# 2    1.0
# 4    1.0
# 5    1.0
# 6    1.0
# Name: Number_of_bathrooms, dtype: float64

# %% [markdown]
# # Saving Clean Dataframe file

# %%
#Saving single file output 
df_airbnb_clean.to_csv("Airbnb_cleaned.csv", index=False)

# %%
df_airbnb_clean.head()
# Out:
#       id                                        description  host_id  \
# 0   2818  Quiet Garden View Room & Super Fast WiFi<br />...     3159
# 2  25428  Lovely apt in Centre ( lift & fireplace) near ...    56142
# 4  28871  <b>The space</b><br />In a monumental house ri...   124245
# 5  29051  This room can also accomodate 2 people.  For a...   124245
# 6  31080  <b>The space</b><br />My apartment is light an...   133488
#
#   host_is_superhost host_has_profile_pic host_identity_verified  \
# 0                 t                    t                      t
# 2                 t                    t                      f
# 4                 t                    t                      t
# 5                 t                    t                      t
# 6                 f                    t                      t
#
#                    neighbourhood_cleansed  latitude  longitude  \
# 0  Oostelijk Havengebied - Indische Buurt  52.36575    4.94142
# 2                            Centrum-West  52.37297    4.88339
# 4                            Centrum-Oost  52.36610    4.88953
# 5                            Centrum-Oost  52.36607    4.89100
# 6                                    Zuid  52.35132    4.84838
#
#                property_type  ... maximum_nights  has_availability  \
# 0  Private room in apartment  ...           1125                 t
# 2           Entire apartment  ...            180                 t
# 4  Private room in apartment  ...           1825                 t
# 5  Private room in apartment  ...            730                 t
# 6           Entire apartment  ...            365                 t
#
#    availability_365  number_of_reviews  instant_bookable  \
# 0               139                278                 t
# 2               251                  5                 f
# 4               338                336                 f
# 5               355                480                 f
# 6                 0                 32                 f
#
#    calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                               1                                           0
# 2                               1                                           1
# 4                               2                                           0
# 5                               2                                           0
# 6                               1                                           1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 2                                             0
# 4                                             2
# 5                                             2
# 6                                             0
#
#    calculated_host_listings_count_shared_rooms Number_of_bathrooms
# 0                                            0                 1.5
# 2                                            0                 1.0
# 4                                            0                 1.0
# 5                                            0                 1.0
# 6                                            0                 1.0
#
# [5 rows x 25 columns]
